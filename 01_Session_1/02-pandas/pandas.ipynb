# %%
import pandas as pd

# %% [markdown]
# 1.0 DataFrame and Series Definition

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2.0 DataFrame Creation

# %% [markdown]
# 2.1 Dictionary

# %%
dict = {
        "name":["Pedro","Antonio","Ángela","María"],
        "edad": [18,54,25,42],
        "email": ["pedro@gmail.com","antonio@hotmail.com","angela@yahoo.com","maria@icloud.com"]}
dict
# Out:
# {'name': ['Pedro', 'Antonio', 'Ángela', 'María'],
#  'edad': [18, 54, 25, 42],
#  'email': ['pedro@gmail.com',
#   'antonio@hotmail.com',
#   'angela@yahoo.com',
#   'maria@icloud.com']}

# %%
df = pd.DataFrame(dict)

# %%
df
# Out:
#       name  edad                email
# 0    Pedro    18      pedro@gmail.com
# 1  Antonio    54  antonio@hotmail.com
# 2   Ángela    25     angela@yahoo.com
# 3    María    42     maria@icloud.com

# %% [markdown]
# 2.2 n-array

# %%
n_darray = [["name","edad","email"],
["Pedro",18,"pedro@gmail.com"],
["Antonio",54,"antonio@hotmail.com"],
["Ángela",25,"angela@yahoo.com"],
["María",42,"maria@icloud.com"]]

# %%
n_darray
# Out:
# [['name', 'edad', 'email'],
#  ['Pedro', 18, 'pedro@gmail.com'],
#  ['Antonio', 54, 'antonio@hotmail.com'],
#  ['Ángela', 25, 'angela@yahoo.com'],
#  ['María', 42, 'maria@icloud.com']]

# %%
df_1 = pd.DataFrame(n_darray)

# %%
df_1
# Out:
#          0     1                    2
# 0     name  edad                email
# 1    Pedro    18      pedro@gmail.com
# 2  Antonio    54  antonio@hotmail.com
# 3   Ángela    25     angela@yahoo.com
# 4    María    42     maria@icloud.com

# %%
headers = n_darray[0]
headers
# Out:
# ['name', 'edad', 'email']

# %%
body = n_darray[1:]

# %%
body
# Out:
# [['Pedro', 18, 'pedro@gmail.com'],
#  ['Antonio', 54, 'antonio@hotmail.com'],
#  ['Ángela', 25, 'angela@yahoo.com'],
#  ['María', 42, 'maria@icloud.com']]

# %%
df_1= pd.DataFrame(body, columns = headers)

# %%
df_1
# Out:
#       name  edad                email
# 0    Pedro    18      pedro@gmail.com
# 1  Antonio    54  antonio@hotmail.com
# 2   Ángela    25     angela@yahoo.com
# 3    María    42     maria@icloud.com

# %% [markdown]
# 3.0 Get header list from DataFrame

# %%
df.columns
# Out:
# Index(['name', 'edad', 'email'], dtype='object')

# %%
headers = df.columns.tolist()

# %%
headers
# Out:
# ['name', 'edad', 'email']

# %% [markdown]
# 4.0 Size of DataFrame

# %%
df.shape
# Out:
# (4, 3)

# %%
nrows = df.shape[0]
ncols= df.shape[1]

# %%
nrows
# Out:
# 4

# %%
ncols
# Out:
# 3

# %% [markdown]
# 5.0 Create DataFrame from csv

# %%
df_2 = pd.read_csv("createdf.csv", sep= ",")

# %%
df_2
# Out:
#       name  edad                email
# 0    Pedro    18      pedro@gmail.com
# 1  Antonio    54  antonio@hotmail.com
# 2   Ángela    25     angela@yahoo.com
# 3    María    42     maria@icloud.com

# %%
df_2.to_excel("createdf.xlsx")

# %% [markdown]
# 6.0 read from excel

# %%
df_3 = pd.read_excel("createdf.xlsx")

# %%
df_3
# Out:
#       name  edad                email
# 0    Pedro    18      pedro@gmail.com
# 1  Antonio    54  antonio@hotmail.com
# 2   Ángela    25     angela@yahoo.com
# 3    María    42     maria@icloud.com

# %% [markdown]
# 7.0 Write df to csv

# %%
df_3.to_csv("writecsv.csv", index = False)

# %% [markdown]
# 8.0 Write df to excel

# %%
df_3.to_excel("writeexcel.xlsx", index = False)

# %% [markdown]
# 9.0 Select data from df

# %% [markdown]
# 9.1 loc

# %%
df_loc = df_3.loc[0,"email"]

# %%
df_loc
# Out:
# 'pedro@gmail.com'

# %%
df_loc = df_3.loc[[0,1],["name","email"]]

# %%
df_loc
# Out:
#       name                email
# 0    Pedro      pedro@gmail.com
# 1  Antonio  antonio@hotmail.com

# %%
df_loc = df_3.loc[1:,["edad","email"]]

# %%
df_loc
# Out:
#    edad                email
# 1    54  antonio@hotmail.com
# 2    25     angela@yahoo.com
# 3    42     maria@icloud.com

# %% [markdown]
# 9.1 iloc

# %%
df_iloc = df_3.iloc[0,1]

# %%
df_iloc
# Out:
# 18

# %%
df_iloc = df_3.iloc[0,[1,2]]

# %%
df_iloc
# Out:
# edad                  18
# email    pedro@gmail.com
# Name: 0, dtype: object

# %%
df_iloc = df_3.iloc[1:,1:]

# %%
df_iloc
# Out:
#    edad                email
# 1    54  antonio@hotmail.com
# 2    25     angela@yahoo.com
# 3    42     maria@icloud.com

# %% [markdown]
# 10.0 Filters

# %%
df
# Out:
#       name  edad                email
# 0    Pedro    18      pedro@gmail.com
# 1  Antonio    54  antonio@hotmail.com
# 2   Ángela    25     angela@yahoo.com
# 3    María    42     maria@icloud.com

# %%
filter = df["edad"] > 26

# %%
filter
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# Name: edad, dtype: bool

# %%
df[filter]
# Out:
#       name  edad                email
# 1  Antonio    54  antonio@hotmail.com
# 3    María    42     maria@icloud.com

# %%
df[df["edad"] > 26]
# Out:
#       name  edad                email
# 1  Antonio    54  antonio@hotmail.com
# 3    María    42     maria@icloud.com

# %% [markdown]
# 11.0 Sorting

# %%
df_sorted = df.sort_values(by="edad", ascending = False)

# %%
df_sorted
# Out:
#       name  edad                email
# 1  Antonio    54  antonio@hotmail.com
# 3    María    42     maria@icloud.com
# 2   Ángela    25     angela@yahoo.com
# 0    Pedro    18      pedro@gmail.com

# %%
df_sorted = df.sort_values(by=["edad","name"], ascending = [True,False])

# %%
df_sorted
# Out:
#       name  edad                email
# 0    Pedro    18      pedro@gmail.com
# 2   Ángela    25     angela@yahoo.com
# 3    María    42     maria@icloud.com
# 1  Antonio    54  antonio@hotmail.com

# %% [markdown]
# 12.0 Add and Delete Columns

# %%
df["estudios"] = ["actuario","ingeniero","medico","profesor"]

# %%
df
# Out:
#       name  edad                email   estudios
# 0    Pedro    18      pedro@gmail.com   actuario
# 1  Antonio    54  antonio@hotmail.com  ingeniero
# 2   Ángela    25     angela@yahoo.com     medico
# 3    María    42     maria@icloud.com   profesor

# %%
df.drop("estudios", axis=1, inplace = True)

# %%
df
# Out:
#       name  edad                email
# 0    Pedro    18      pedro@gmail.com
# 1  Antonio    54  antonio@hotmail.com
# 2   Ángela    25     angela@yahoo.com
# 3    María    42     maria@icloud.com

# %%
df.loc[df.shape[0]] = ["Jesus", 10 , None]

# %%
df
# Out:
#       name  edad                email
# 0    Pedro    18      pedro@gmail.com
# 1  Antonio    54  antonio@hotmail.com
# 2   Ángela    25     angela@yahoo.com
# 3    María    42     maria@icloud.com
# 4    Jesus    10                 None

# %%
df.drop(df.shape[0]-1, axis = 0)
# Out:
#       name  edad                email
# 0    Pedro    18      pedro@gmail.com
# 1  Antonio    54  antonio@hotmail.com
# 2   Ángela    25     angela@yahoo.com
# 3    María    42     maria@icloud.com

# %%
headers = df.columns

# %% [markdown]
# 14.0 Loops over columns

# %%
for i in headers:
    
    if (df.loc[:,i].dtype == "object"):
        print(df.loc[:,i].str.upper())
# Out:
# 0      PEDRO
# 1    ANTONIO
# 2     ÁNGELA
# 3      MARÍA
# 4      JESUS
# Name: name, dtype: object
# 0        PEDRO@GMAIL.COM
# 1    ANTONIO@HOTMAIL.COM
# 2       ANGELA@YAHOO.COM
# 3       MARIA@ICLOUD.COM
# 4                   None
# Name: email, dtype: object

# %% [markdown]
# 15.0 Loops over rows

# %%
df
# Out:
#       name  edad                email
# 0    Pedro    18      pedro@gmail.com
# 1  Antonio    54  antonio@hotmail.com
# 2   Ángela    25     angela@yahoo.com
# 3    María    42     maria@icloud.com
# 4    Jesus    10                 None

# %%
for i in range(df.shape[0]):
    a = df.iloc[i].tolist()
    if ("Antonio" in a):
        print(a)
    else:
        print("no antonio")
# Out:
# no antonio
# ['Antonio', 54, 'antonio@hotmail.com']
# no antonio
# no antonio
# no antonio
